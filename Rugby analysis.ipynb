# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Rugby points analysis
#
# In order to understand the difference between Rugby Union and Rugby League, I shall analyse the total score averages across tournaments 8 years back. Undeniably, there shall be a total score disparity between the two types of rugby due to the fact that each variation of rugby has different points assigned to each scoring option. These point diffences shall be discussed in the following section:

# %% [markdown]
# **Rugby Union**
#
# **1)** Try = 5 points
#
# **2)** Conversion = 2 points (possible after Try)
#
# **3)** Penalty kick = 3 points
#
# **4)** Drop goal = 3 points

# %% [markdown]
# **Rugby League**
#
# **1)** Try = 4 points
#
# **2)** Conversion = 2 points (possible after Try)
#
# **3)** Penalty kick = 2 points
#
# **4)** Drop goal = 1 points

# %% [markdown]
# ## **Index**
#
# 1. [Data import and cleaning](#Data-import-and-cleaning)
#
#     1.1. [Rugby Union](#Rugby-Union)
#
#     1.2. [Rugby League](#Rugby-League)
#
#
# 2. [Visualizations](#Visualizations)
#
#     2.1. [Visual analysis (Rugby Union)](#Visual-analysis-(Rugby-Union))
#
#     2.2. [Visual analysis (Rugby League)](#Visual-analysis-(Rugby-League))

# %% [markdown]
# ## Data import and cleaning
#
# For the purpose of this analysis, I have scraped data from https://www.livesport.cz/ using Power Automate. I have selected one specific tournament for each rugby type. The **European Rugby Champions Cup** has been chosen for the Rugby Union and **Super League** for Rugby League.

# %% [markdown]
# ### Rugby Union
#
# The data has been scraped from https://www.livesport.cz/ragby/evropa/european-rugby-champions-cup/archiv/ for the past 8 seasons of European Rugby Championship Cup. I have included the current season, which at the time of this analysis has not yet finished, but it was 2 rounds from ending.

# %%
dfu = pd.read_excel(r'C:\Users\spijak\OneDrive - FORTUNA GAME a.s\Desktop\Rugby analysis\rugby union\master_rugby_data.xlsx')

# %%
dfu
# Out:
#           year EUROPEEuropean Rugby Champions Cup - Play Offs  \
# 0    2014/2015                                       Clermont
# 1    2014/2015                                         Toulon
# 2    2014/2015                                       Clermont
# 3    2014/2015                                         Toulon
# 4    2014/2015                                      Racing 92
# ..         ...                                            ...
# 519  2021/2022                                       Clermont
# 520  2021/2022                                Bordeaux Begles
# 521  2021/2022                                       Leinster
# 522  2021/2022                                  Cardiff Rugby
# 523  2021/2022                             Northampton Saints
#
#            Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0              Toulon        18.0        11.0         7.0        24.0
# 1            Leinster        25.0         6.0         6.0        20.0
# ...

# %%
dfu.columns
# Out:
# Index(['year', 'EUROPEEuropean Rugby Champions Cup - Play Offs', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8'],
#       dtype='object')

# %% [markdown]
# ### Rugby League
#
# The data for Rugby League has been scraped from https://www.livesport.cz/rugby-league/anglie/super-league/archiv/ for the past full 8 seasons of Super League. I have not included the current season, which at the time of this analysis still had almost 10 rounds to go.

# %%
dfl = pd.read_excel(r'C:\Users\spijak\OneDrive - FORTUNA GAME a.s\Desktop\Rugby analysis\rugby league\master_rugby_data.xlsx')

# %%
dfl
# Out:
#       year ANGLIESuper League - Play Off        Unnamed: 2  Unnamed: 3  \
# 0     2014                     St Helens             Wigan        14.0
# 1     2014                         Wigan        Warrington        16.0
# 2     2014                     St Helens  Catalans Dragons        30.0
# 3     2014                  Huddersfield  Catalans Dragons        16.0
# 4     2014                    Castleford        Warrington        14.0
# ...    ...                           ...               ...         ...
# 2503  2021                       Hull FC      Huddersfield        22.0
# 2504  2021              Catalans Dragons           Hull KR        29.0
# 2505  2021                     Wakefield             Leeds        22.0
# 2506  2021                         Leigh             Wigan        18.0
# 2507  2021                     St Helens           Salford        29.0
#
#       Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# ...

# %%
dfl.columns
# Out:
# Index(['year', 'ANGLIESuper League - Play Off', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %% [markdown]
# #### Updating column names

# %%
#rugby union
dfu.columns = ['year', 'home team', 'away team', 'home total score', 'home FH score', 'home SH score', 'away total score', 'away FH score', 'away SH score']

#rugby league
dfl.columns = ['year', 'home team', 'away team', 'home total score', 'home FH score', 'home SH score', 'away total score', 'away FH score', 'away SH score']

# %% [markdown]
# #### Dropping unwated rows

# %%
dfu[dfu['home team'] == 'EUROPEEuropean Rugby Champions Cup']
# Out:
#           year                           home team away team  \
# 7    2014/2015  EUROPEEuropean Rugby Champions Cup       NaN
# 78   2015/2016  EUROPEEuropean Rugby Champions Cup       NaN
# 149  2016/2017  EUROPEEuropean Rugby Champions Cup       NaN
# 217  2017/2018  EUROPEEuropean Rugby Champions Cup       NaN
# 289  2018/2019  EUROPEEuropean Rugby Champions Cup       NaN
# 359  2019/2020  EUROPEEuropean Rugby Champions Cup       NaN
# 435  2020/2021  EUROPEEuropean Rugby Champions Cup       NaN
# 480  2021/2022  EUROPEEuropean Rugby Champions Cup       NaN
#
#      home total score  home FH score  home SH score  away total score  \
# 7                 NaN            NaN            NaN               NaN
# 78                NaN            NaN            NaN               NaN
# 149               NaN            NaN            NaN               NaN
# 217               NaN            NaN            NaN               NaN
# ...

# %%
dfl[dfl['home team'] == 'ANGLIESuper League - Play Off']
# Out:
#       year                      home team away team  home total score  \
# 105   2014  ANGLIESuper League - Play Off       NaN               NaN
# 308   2015  ANGLIESuper League - Play Off       NaN               NaN
# 444   2015  ANGLIESuper League - Play Off       NaN               NaN
# 448   2015  ANGLIESuper League - Play Off       NaN               NaN
# 678   2016  ANGLIESuper League - Play Off       NaN               NaN
# 812   2016  ANGLIESuper League - Play Off       NaN               NaN
# 816   2016  ANGLIESuper League - Play Off       NaN               NaN
# 1048  2017  ANGLIESuper League - Play Off       NaN               NaN
# 1173  2017  ANGLIESuper League - Play Off       NaN               NaN
# 1177  2017  ANGLIESuper League - Play Off       NaN               NaN
# 1400  2018  ANGLIESuper League - Play Off       NaN               NaN
# 1533  2018  ANGLIESuper League - Play Off       NaN               NaN
# ...

# %%
dfu_a = dfu.fillna(0)
dfl_a = dfl.fillna(0)

# %%
#drop rows with EUROPEEuropean Rugby Champions Cup
dfu_a.drop(dfu_a.index[dfu_a['home team'] == 0], inplace=True)

#drop rows with ANGLIESuper League - Play Off
dfl_a.drop(dfl_a.index[dfl_a['home team'] == 0], inplace=True)

# %%
#drop rows with EUROPEEuropean Rugby Champions Cup - Qualification
dfu_a.drop(dfu_a.index[dfu_a['away team'] == 0], inplace=True)

#drop rows with EUROPEEuropean Rugby Champions Cup - Qualification
dfl_a.drop(dfl_a.index[dfl_a['away team'] == 0], inplace=True)

# %% [markdown]
# ### Clean dataframes
#
# Finally, we arrive at the clean dataset for each rugby type. These shall be further employed for the initial analysis.

# %% [markdown]
# #### Rugby union

# %% [markdown]
# The data set contains a total amount of **512** matches.

# %%
dfu_a
# Out:
#           year           home team         away team  home total score  \
# 0    2014/2015            Clermont            Toulon              18.0
# 1    2014/2015              Toulon          Leinster              25.0
# 2    2014/2015            Clermont          Saracens              13.0
# 3    2014/2015              Toulon             Wasps              32.0
# 4    2014/2015           Racing 92          Saracens              11.0
# ..         ...                 ...               ...               ...
# 519  2021/2022            Clermont            Ulster              23.0
# 520  2021/2022     Bordeaux Begles  Leicester Tigers              13.0
# 521  2021/2022            Leinster              Bath              45.0
# 522  2021/2022       Cardiff Rugby  Stade Toulousain               7.0
# 523  2021/2022  Northampton Saints         Racing 92              14.0
#
#      home FH score  home SH score  away total score  away FH score  \
# ...

# %%
dfu_a.describe()
# Out:
#        home total score  home FH score  home SH score  away total score  \
# count        512.000000     512.000000     512.000000        512.000000
# mean          26.041016      12.515625      12.974609         19.593750
# std           13.189878       7.931442       9.140421         10.635161
# min            0.000000       0.000000       0.000000          0.000000
# 25%           17.000000       7.000000       6.000000         13.000000
# 50%           24.500000      12.000000      12.000000         19.000000
# 75%           33.000000      17.000000      19.000000         26.000000
# max           89.000000      42.000000      52.000000         64.000000
#
#        away FH score  away SH score
# count     512.000000     512.000000
# mean        9.880859       9.572266
# std         7.005133       7.061004
# min         0.000000       0.000000
# 25%         5.000000       5.000000
# 50%        10.000000       8.000000
# 75%        14.000000      14.000000
# ...

# %% [markdown]
# #### Rugby League

# %% [markdown]
# The data set contains a total amount of **2 250** matches.

# %%
dfl_a
# Out:
#       year         home team         away team  home total score  \
# 0     2014         St Helens             Wigan              14.0
# 1     2014             Wigan        Warrington              16.0
# 2     2014         St Helens  Catalans Dragons              30.0
# 3     2014      Huddersfield  Catalans Dragons              16.0
# 4     2014        Castleford        Warrington              14.0
# ...    ...               ...               ...               ...
# 2503  2021           Hull FC      Huddersfield              22.0
# 2504  2021  Catalans Dragons           Hull KR              29.0
# 2505  2021         Wakefield             Leeds              22.0
# 2506  2021             Leigh             Wigan              18.0
# 2507  2021         St Helens           Salford              29.0
#
#       home FH score  home SH score  away total score  away FH score  \
# 0               2.0           12.0               6.0            6.0
# ...

# %%
dfl_a.describe()
# Out:
#               year  home total score  home FH score  home SH score  \
# count  2250.000000       2250.000000    2250.000000    2250.000000
# mean   2017.291556         25.023556      12.071556      12.921778
# std       2.237831         13.626631       8.216974       8.629425
# min    2014.000000          0.000000       0.000000       0.000000
# 25%    2015.000000         16.000000       6.000000       6.000000
# 50%    2017.000000         24.000000      12.000000      12.000000
# 75%    2019.000000         34.000000      17.000000      18.000000
# max    2021.000000         84.000000      46.000000      50.000000
#
#        away total score  away FH score  away SH score
# count       2250.000000    2250.000000    2250.000000
# mean          21.004444       9.903111      11.054222
# std           12.346991       7.394279       8.345832
# min            0.000000       0.000000       0.000000
# 25%           12.000000       4.000000       6.000000
# ...

# %% [markdown]
# #### Mean scores across seasons

# %%
#rugby union
dfu_grouped = dfu_a.groupby(['year']).mean()
dfu_grouped
# Out:
#            home total score  home FH score  home SH score  away total score  \
# year
# 2014/2015         23.869565      11.782609      11.898551         17.202899
# 2015/2016         25.391304      11.898551      13.275362         18.260870
# 2016/2017         27.223881      13.761194      13.462687         19.149254
# 2017/2018         27.100000      13.285714      13.814286         20.142857
# 2018/2019         25.897059      12.397059      13.500000         20.044118
# 2019/2020         25.179104      13.164179      12.014925         20.328358
# 2020/2021         26.384615      11.384615      12.076923         21.153846
# 2021/2022         27.555556      11.952381      13.380952         21.301587
#
#            away FH score  away SH score
# year
# 2014/2015       8.594203       8.492754
# 2015/2016       9.362319       8.797101
# 2016/2017       9.358209       9.791045
# 2017/2018      10.728571       9.414286
# 2018/2019      10.279412       9.764706
# ...

# %%
#rugby league
dfl_grouped = dfl_a.groupby(['year']).mean()
dfl_grouped
# Out:
#       home total score  home FH score  home SH score  away total score  \
# year
# 2014         27.811258      13.430464      14.380795         21.854305
# 2015         27.731148      13.540984      14.190164         21.540984
# 2016         25.478405      12.392027      13.086379         21.990033
# 2017         24.299003      11.564784      12.727575         21.418605
# 2018         25.187500      12.319079      12.868421         19.108553
# 2019         23.255245      10.951049      12.272727         21.017483
# 2020         23.275362      10.975845      12.057971         19.729469
# 2021         21.872951      10.717213      11.127049         20.983607
#
#       away FH score  away SH score
# year
# 2014       9.463576      12.390728
# 2015      10.390164      11.150820
# 2016      10.411960      11.571429
# 2017      10.541528      10.877076
# 2018       8.842105      10.266447
# 2019      10.055944      10.954545
# 2020       9.690821      10.019324
# ...

# %% [markdown]
# ### Visualizations
#
# In this section, I focus on the data visualizations. I provide an overview of the development of total match points across seasons as well as first half and second half distribution of points. Additionally, I focus on the points development of the teams that won each season.

# %% [markdown]
# ####  Visual analysis (Rugby Union)

# %%
plt.rcParams["figure.figsize"] = (10,6)

X = ['2014/2015','2015/2016','2016/2017','2017/2018','2018/2019','2019/2020','2020/2021','2021/2022']
Hpoints = dfu_a.groupby(['year'])['home total score'].mean()
Apoints = dfu_a.groupby(['year'])['away total score'].mean()
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, Hpoints, 0.4, label = 'Home')
plt.bar(X_axis + 0.2, Apoints, 0.4, label = 'Away')
  
plt.xticks(X_axis, X, rotation=90)
plt.xlabel("Season")
plt.ylabel("Total points")
plt.title("Average total points per season (Rugby Union)")
plt.legend()
plt.show()

# %%
winner_2020 = dfu_a[(dfu_a['year'] == '2020/2021') & ((dfu_a['home team'] == 'Stade Toulousain') | (dfu_a['away team'] == 'Stade Toulousain'))]
winner_2020
# Out:
#           year         home team         away team  home total score  \
# 420  2020/2021       La Rochelle  Stade Toulousain              17.0
# 422  2020/2021  Stade Toulousain   Bordeaux Begles              21.0
# 423  2020/2021          Clermont  Stade Toulousain              12.0
# 431  2020/2021           Munster  Stade Toulousain              33.0
# 438  2020/2021  Stade Toulousain     Exeter Chiefs              28.0
# 458  2020/2021            Ulster  Stade Toulousain              22.0
#
#      home FH score  home SH score  away total score  away FH score  \
# 420           12.0            5.0              22.0            9.0
# 422            8.0           13.0               9.0            6.0
# 423            6.0            6.0              21.0            6.0
# 431           16.0           17.0              40.0            9.0
# 438            0.0            0.0               0.0            0.0
# 458           12.0           10.0              29.0           14.0
#
# ...

# %%
def team_score(team, year):
    a = dfu_a[(dfu_a['year'] == year) & ((dfu_a['home team'] == team) | (dfu_a['away team'] == team))]
    
#     if a[a['home team']] == team:
#             sum(a[a['away total score']])
    display(a)

# %%
dfu_a['home team'].unique()
# Out:
# array(['Clermont', 'Toulon', 'Racing 92', 'Leinster', 'Munster', 'Bath',
#        'Montpellier', 'Scarlets', 'Ulster', 'Benetton',
#        'Northampton Saints', 'Castres Olympique', 'Wasps', 'Ospreys',
#        'Stade Toulousain', 'Glasgow', 'Harlequins', 'Sale Sharks',
#        'Saracens', 'Leicester Tigers', 'Stade Francais', 'Exeter Chiefs',
#        'Union Sportive Oyonnax', 'Bordeaux Begles', 'Gloucester', 'Zebre',
#        'Connacht', 'La Rochelle', 'Edinburgh', 'Cardiff Rugby',
#        'Newcastle Falcons', 'Lyon', 'Dragons', 'Bristol'], dtype=object)

# %%
team_score('La Rochelle', '2020/2021')
# Out:
#           year    home team         away team  home total score  \
# 420  2020/2021  La Rochelle  Stade Toulousain              17.0
# 421  2020/2021  La Rochelle          Leinster              32.0
# 426  2020/2021  La Rochelle       Sale Sharks              45.0
# 433  2020/2021   Gloucester       La Rochelle              16.0
# 443  2020/2021  La Rochelle              Bath              28.0
# 452  2020/2021    Edinburgh       La Rochelle               8.0
#
#      home FH score  home SH score  away total score  away FH score  \
# 420           12.0            5.0              22.0            9.0
# 421           12.0           20.0              23.0           13.0
# 426           18.0           27.0              21.0           16.0
# 433           13.0            3.0              27.0           15.0
# 443            0.0            0.0               0.0            0.0
# 452            3.0            5.0              13.0            8.0
#
#      away SH score
# 420           13.0
# ...

# %% [markdown]
# #### Visual analysis (Rugby League)

# %%
plt.rcParams["figure.figsize"] = (10,6)

X_L = ['2014','2015','2016','2017','2018','2019','2020','2021']
H_Lpoints = dfl_a.groupby(['year'])['home total score'].mean()
A_Lpoints = dfl_a.groupby(['year'])['away total score'].mean()
  
X_Laxis = np.arange(len(X))
  
plt.bar(X_Laxis - 0.2, H_Lpoints, 0.4, label = 'Home')
plt.bar(X_Laxis + 0.2, A_Lpoints, 0.4, label = 'Away')
  
plt.xticks(X_Laxis, X_L, rotation=90)
plt.xlabel("Season")
plt.ylabel("Total points")
plt.title("Average total points per season (Rugby League)")
plt.legend()
plt.show()
